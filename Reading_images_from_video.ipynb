# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import imageio
# %matplotlib inline

# %%
video_path = 'data/'
for filename in os.listdir(video_path):
    if filename.endswith('.MP4'):
        vid = imageio.get_reader(video_path+filename, 'ffmpeg')
        image = vid.get_data(3)
        plt.figure(figsize=(100,9))
        plt.imshow(vid.get_data(5000)[::,::,2])
        # here the image is represented as an array and can be passed to plt.imshow to render it as an image.
